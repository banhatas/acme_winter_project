# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
domain = np.linspace(0,3,100)
a = 2
control = (a*(domain - 1.6))**4
plt.figure(dpi=300)
plt.plot(domain, control, color='purple')
plt.xlabel("Movement")
plt.ylabel("Cost")
plt.ylim(0, 15)
plt.show()
